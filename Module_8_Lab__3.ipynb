# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinaya-09/ABHINAYA_FMML_LABS_PROJECTS/blob/main/Module_8_Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 10:00:44--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   195MB/s    in 0.4s
#
# 2024-03-30 10:00:44 (195 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3367   1605.06742v1  A rapid pattern-recognition approach to charac...  stat
# 10459   1210.2085v2  We study statistical risk minimization problem...  stat
# 22696  1704.07554v2  The current work characterizes the users of a ...  stat
# 18754   1111.6401v1  Nowadays, e-government has emerged as a govern...    cs
# 29101  1708.04317v1  In this paper, we propose a novel convolutiona...    cs
# ...             ...                                                ...   ...
# 22774  1706.03779v2  Latent feature modeling allows capturing the l...  stat
# 5361    1304.5758v2  We consider the stochastic multi-armed bandit ...  stat
# 20906  1705.02175v1  Logic-based event recognition systems infer oc...    cs
# 40725   1202.4473v1  We present a new bandit algorithm, SAO (Stocha...    cs
# 36671   1307.6883v2  A prototype tool to assist architects during t...    cs
#
#                                                    title  year  \
# 3367   A Rapid Pattern-Recognition Method for Driving...  2016
# 10459                             Privacy Aware Learning  2012
# 22696  A relevance-scalability-interpretability trade...  2017
# 18754   Graph based E-Government web service composition  2011
# 29101  An ELU Network with Total Variation for Image ...  2017
# ...                                                  ...   ...
# 22774  General Latent Feature Models for Heterogeneou...  2017
# 5361   Prior-free and prior-dependent regret bounds f...  2013
# 20906   Distributed Online Learning of Event Definitions  2017
# 40725  The best of both worlds: stochastic and advers...  2012
# 36671  A gradient descent technique coupled with a dy...  2013
#
#                                                 keywords
# 3367   [recognition, characterize, negotiating, recog...
# 10459  [statistical, minimization, confidential, fram...
# 22696  [characterizes, streaming, behavioral, combina...
# 18754  [government, government, efficiency, administr...
# 29101  [convolutional, denoising, exponential, activa...
# ...                                                  ...
# 22774  [capturing, structure, responsible, generating...
# 5361   [stochastic, distribution, distributions, inte...
# 20906  [recognition, occurrences, definitions, recogn...
# 40725  [algorithm, adversarial, essentially, adversar...
# 36671  [prototype, architects, developed, consisting,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3367     [recognition, characterize, negotiating, recog...
# 10459    [statistical, minimization, confidential, fram...
# 22696    [characterizes, streaming, behavioral, combina...
# 18754    [government, government, efficiency, administr...
# 29101    [convolutional, denoising, exponential, activa...
#                                ...
# 18916    [continuous, variables, animportant, condition...
# 5307     [describes, optimization, incorporates, candid...
# 22003    [introduce, computationally, effective, algori...
# 20625    [propositional, inductive, definitions, semant...
# 16947    [important, argumentation, recognize, fallacie...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8701 words.
# Out of those 4538 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="29f284ae-a1a5-4310-8fc1-233d4846d9b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29f284ae-a1a5-4310-8fc1-233d4846d9b8")) {                    Plotly.newPlot(                        "29f284ae-a1a5-4310-8fc1-233d4846d9b8",                        [{"x":["parameters","effective","aggressive","hyperplane","discriminate","characterize","classifying","experiment","developed","validation","predicting","clustering","conducted","recognition","behaviors","minimization","procedures","procedure","estimator","confidential","preserves","statistical","framework","convergence","estimation","establish","consequence","applicable","maturation","information","characterizes","constructed","highlights","behavioral","represent","exhibiting","scalability","streaming","characterizations","combination","successfully","application","timelines","demonstration","predictive","individual","temporally","interpretability","relevance","uncovering","granularity","consequent","insightful","population","providing","guarantees","understanding","indispensable","stability","interesting","evolution","characteristics","optimizing","potential","government","computation","challenges","communication","relationship","composition","technologies","algorithm","elementary","efficiency","exploiting","processes","suitability","performance","convolutional","variation","diffusion","outperforms","connection","normalization","trainable","rationale","nonlinear","experiments","approaches","corresponding","denoising","exponential","iterations","investigate","activation","regularized","innovative","analyzing","randomized","extensive","minimizing","available","linguistic","combining","implementing","documents","respective","resolution","therefore","situations","acceptable","retrieval","contribute","extraction","sentences","displayed","resources","convenient","highlighted","character","complementary","difficulty","extracted","representation","coefficients","consistent","compensating","transferred","collaborative","robustness","transferring","implemented","classification","demonstrated","implement","candidate","alternative","achieving","conclusions","illustrate","demonstrate","introduce","classifiers","important","selection","scientific","classifier","advantage","estimated","instability","generalization","significantly","simulations","selecting","incorporate","prototypical","reproducibility","initially","predictions","potentially","specifically","different","principle","simultaneously","inferences","treatment","fundamental","categorial","viewpoint","functions","quantifiers","theoretical","syntactical","semantics","practical","according","construction","computational","operators","evaluated","experimental","biological","representing","properties","distinguishable","discrimination","plasticity","functionality","consisting","simulation","introduces","categories","biologically","discriminative","realistic","correlated","involving","signature","dependent","efficient"],"y":[241,242,6,3,16,44,36,75,200,53,85,125,69,384,30,51,27,115,25,1,9,180,540,113,194,45,23,51,0,680,10,63,6,27,108,12,27,15,10,135,84,263,1,13,50,113,19,18,32,4,12,2,1,41,82,55,170,4,39,68,56,84,47,141,7,135,136,65,81,23,34,764,16,132,64,95,11,864,384,48,23,271,43,39,26,5,65,619,416,125,41,40,26,120,35,45,11,63,21,155,37,325,64,113,18,73,20,135,133,53,10,94,27,129,72,8,78,11,5,55,56,45,117,357,38,87,1,19,29,90,15,84,546,105,59,46,116,78,19,74,566,345,130,345,143,49,172,103,46,10,104,271,41,35,68,6,2,21,69,52,187,784,65,101,16,41,73,2,39,223,3,160,3,102,132,91,61,291,37,148,379,38,85,206,1,21,7,11,55,86,80,71,18,103,67,30,45,17,71,396],"type":"bar"},{"x":["parameters","effective","aggressive","hyperplane","discriminat ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4538,), (4538, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Ridge</span> <span style=''>and</span> <span style=''>Lasso</span> <span style='background-color:rgba(255, 0, 0, 0.4967462039045552);'>Regression</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Partially</span> <span style=''>Observed</span> <span style='background-color:rgba(0, 255, 0, 0.4157303370786517);'>Attributes</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>most</span> <span style=''>common</span> <span style=''>variants</span> <span style=''>of</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.4967462039045552);'>regression</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>Ridge</span> <span style=''>Lasso</span> <span style=''>and</span> <span style=''>Support</span> <span style=''>vector</span> <span style='background-color:rgba(255, 0, 0, 0.4967462039045552);'>regression</span> <span style=''>in</span> <span style=''>a</span> <span style=''>setting</span> <span style=''>where</span> <span style=''>the</span> <span style=''>learner</span> <span style=''>is</span> <span style=''>allowed</span> <span style=''>to</span> <span style=''>observe</span> <span style=''>only</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4157303370786517);'>attributes</span> <span style=''>of</span> <span style=''>each</span> <span style=''>example</span> <span style=''>at</span> <span style=''>training</span> <span style=''>time</span> <span style=''>We</span> <span style=''>present</span> <span style=''>simple</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>for</span> <span style=''>Lasso</span> <span style=''>and</span> <span style=''>Ridge</span> <span style='background-color:rgba(255, 0, 0, 0.4967462039045552);'>regression</span> <span style=''>they</span> <span style=''>need</span> <span style=''>the</span> <span style=''>same</span> <span style=''>total</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4157303370786517);'>attributes</span> <span style=''>(up</span> <span style=''>to</span> <span style=''>constants)</span> <span style=''>as</span> <span style=''>do</span> <span style=''>full</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>reaching</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>accuracy</span> <span style=''>For</span> <span style=''>Support</span> <span style=''>vector</span> <span style='background-color:rgba(255, 0, 0, 0.4967462039045552);'>regression</span> <span style=''>we</span> <span style=''>require</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponentially</span> <span style=''>less</span> <span style='background-color:rgba(0, 255, 0, 0.4157303370786517);'>attributes</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>By</span> <span style=''>that</span> <span style=''>we</span> <span style=''>resolve</span> <span style=''>an</span> <span style=''>open</span> <span style=''>problem</span> <span style=''>recently</span> <span style=''>posed</span> <span style=''>by</span> <span style=''>Cesa</span> <span style=''>Bianchi</span> <span style=''>et</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Copula</span> <span style=''>Mixture</span> <span style=''>Model</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dependency</span> <span style=''>seeking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>copula</span> <span style=''>mixture</span> <span style=''>model</span> <span style=''>to</span> <span style=''>perform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependency</span> <span style=''>seeking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>when</span> <span style=''>co</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>occurring</span> <span style=''>samples</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>data</span> <span style=''>sources</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>The</span> <span style=''>model</span> <span style=''>takes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style=''>the</span> <span style=''>great</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>flexibility</span> <span style=''>offered</span> <span style=''>by</span> <span style=''>the</span> <span style=''>copulas</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>extend</span> <span style=''>mixtures</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Canonical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Correlation</span> <span style=''>Analysis</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>data</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>densities</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulate</span> <span style=''>our</span> <span style=''>model</span> <span style=''>as</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>Bayesian</span> <span style=''>mixture</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>MCMC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>and</span> <span style=''>real</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increased</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>flexibility</span> <span style=''>of</span> <span style=''>the</span> <span style=''>copula</span> <span style=''>mixture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>improves</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>results</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.30590339892665463);'>Estimation</span> <span style=''>of</span> <span style=''>linear</span> <span style=''>non</span> <span style=''>gaussian</span> <span style=''>causal</span> <span style=''>models</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.5294117647058824);'>confounding</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variables</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.30590339892665463);'>estimation</span> <span style=''>of</span> <span style=''>linear</span> <span style=''>causal</span> <span style=''>models</span> <span style=''>(also</span> <span style=''>known</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style=''>equation</span> <span style=''>models)</span> <span style=''>from</span> <span style=''>data</span> <span style=''>is</span> <span style=''>a</span> <span style=''>well</span> <span style=''>known</span> <span style=''>problem</span> <span style=''>which</span> <span style=''>has</span> <span style=''>received</span> <span style=''>much</span> <span style='background-color:rgba(0, 255, 0, 0.3725490196078431);'>attention</span> <span style=''>in</span> <span style=''>the</span> <span style=''>past</span> <span style=''>Most</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>has</span> <span style=''>however</span> <span style=''>made</span> <span style=''>an</span> <span style=''>explicit</span> <span style=''>or</span> <span style=''>implicit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6000000000000001);'>gaussianity</span> <span style=''>limiting</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6363636363636364);'>identifiability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>models</span> <span style=''>We</span> <span style=''>have</span> <span style=''>recently</span> <span style=''>shown</span> <span style=''>(Shimizu</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2005</span> <span style=''>Hoyer</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2006)</span> <span style=''>that</span> <span style=''>for</span> <span style=''>non</span> <span style=''>gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3181818181818183);'>distributions</span> <span style=''>the</span> <span style=''>full</span> <span style=''>causal</span> <span style=''>model</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.32846715328467163);'>estimated</span> <span style=''>in</span> <span style=''>the</span> <span style=''>no</span> <span style=''>hidden</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variables</span> <span style=''>case</span> <span style=''>In</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contribution</span> <span style=''>we</span> <span style=''>discuss</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.30590339892665463);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.5294117647058824);'>confounding</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variables</span> <span style=''>are</span> <span style=''>present</span> <span style=''>Although</span> <span style=''>in</span> <span style=''>this</span> <span style=''>case</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uniqueness</span> <span style=''>is</span> <span style=''>no</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Structure</span> <span style=''>Learning</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Models</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Comprehensive</span> <span style=''>Survey</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>combine</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>theory</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>theory</span> <span style=''>to</span> <span style=''>give</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>modeling</span> <span style=''>They</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>description</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Especially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>provide</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style=''>several</span> <span style=''>useful</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>models</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuitive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>On</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style=''>they</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>design</span> <span style=''>and</span> <span style=''>motivate</span> <span style=''>new</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>models</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>additional</span> <span style=''>insights</span> <span style=''>into</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>Complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computations</span> <span style=''> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12740899357601712)
# 	architecture (0.08529621698786581)
# 	information (0.2426837972876517)
# 	segmentation (0.06887937187723055)
# 	experimental (0.13526052819414705)
# 	knowledge (0.1334760885082084)
# 	detection (0.11848679514632406)
# 	recognition (0.13704496788008566)
# 	convolutional (0.13704496788008566)
# 	different (0.2798001427551749)
#
# Some Statistics words are:
# 	numerical (0.1031031031031031)
# 	stochastic (0.13313313313313313)
# 	statistical (0.15215215215215216)
# 	theoretical (0.15115115115115116)
# 	distribution (0.18018018018018017)
# 	algorithm (0.38538538538538536)
# 	estimation (0.18268268268268267)
# 	inference (0.1946946946946947)
# 	dimensional (0.18618618618618618)
# 	regression (0.17267267267267267)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a3a81066-6aa4-4dd9-96ae-b4c577a8f96a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3a81066-6aa4-4dd9-96ae-b4c577a8f96a")) {                    Plotly.newPlot(                        "a3a81066-6aa4-4dd9-96ae-b4c577a8f96a",                        [{"x":["parameters","effective","aggressive","hyperplane","discriminate","characterize","classifying","experiment","developed","validation","predicting","clustering","conducted","recognition","behaviors","minimization","procedures","procedure","estimator","confidential","preserves","statistical","framework","convergence","estimation","establish","consequence","applicable","maturation","information","characterizes","constructed","highlights","behavioral","represent","exhibiting","scalability","streaming","characterizations","combination","successfully","application","timelines","demonstration","predictive","individual","temporally","interpretability","relevance","uncovering","granularity","consequent","insightful","population","providing","guarantees","understanding","indispensable","stability","interesting","evolution","characteristics","optimizing","potential","government","computation","challenges","communication","relationship","composition","technologies","algorithm","elementary","efficiency","exploiting","processes","suitability","performance","convolutional","variation","diffusion","outperforms","connection","normalization","trainable","rationale","nonlinear","experiments","approaches","corresponding","denoising","exponential","iterations","investigate","activation","regularized","innovative","analyzing","randomized","extensive","minimizing","available","linguistic","combining","implementing","documents","respective","resolution","therefore","situations","acceptable","retrieval","contribute","extraction","sentences","displayed","resources","convenient","highlighted","character","complementary","difficulty","extracted","representation","coefficients","consistent","compensating","transferred","collaborative","robustness","transferring","implemented","classification","demonstrated","implement","candidate","alternative","achieving","conclusions","illustrate","demonstrate","introduce","classifiers","important","selection","scientific","classifier","advantage","estimated","instability","generalization","significantly","simulations","selecting","incorporate","prototypical","reproducibility","initially","predictions","potentially","specifically","different","principle","simultaneously","inferences","treatment","fundamental","categorial","viewpoint","functions","quantifiers","theoretical","syntactical","semantics","practical","according","construction","computational","operators","evaluated","experimental","biological","representing","properties","distinguishable","discrimination","plasticity","functionality","consisting","simulation","introduces","categories","biologically","discriminative","realistic","correlated","involving","signature","dependent","efficient","complexity","signatures","supervised","assessment","generality","pedestrians","subsequently","automatically","algorithms","detection","monitoring","detecting","intensively","undergoes","annotated","comparative","informatics","annotation","particular","associated","sufficient","automated","conditions","coordinates","logarithmic","quadratic","independent","constraints","understand","prediction","additivity","characterization","construct","imitating","invariant","recognize","observation","following","interactions","functionally","attributes","embedding","variables","imitation","relationships","background","neighbors","collection","viewpoints","unlabeled","occlusions","representations","environment","reinforcement","effec ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	maturation
# 	permissive
# 	matchings
# 	inductively
# 	subsamples
# 	therapies
# 	integrative
# 	blockwise
# 	activates
# 	determinantal
# 	renormalization
# 	intimately
# 	sketching
# 	submodularity
# 	differentiability
# 	jackknife
# 	oscillations
# 	staleness
# 	therapeutic
# 	integrations
# Some words which never appear in Statistics papers:
# 	government
# 	categorial
# 	quantifiers
# 	syntactical
# 	plasticity
# 	informatics
# 	imitating
# 	functionally
# 	occlusions
# 	offspring
# 	deconstructing
# 	intertwined
# 	consisted
# 	experimenter
# 	monocular
# 	conversational
# 	aircrafts
# 	traveling
# 	featureless
# 	untrimmed

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0714417347502915e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7733333333333333
